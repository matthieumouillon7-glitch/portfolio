# %%
import streamlit as st
import requests
import pandas as pd
from io import BytesIO
import base64
import os
import matplotlib.pyplot as plt
import matplotlib.patches as patches
#from langchain_openai.chat_models import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
st.title(" Let's Discuss about love ! ")
GOOGLE_API_KEY = os.environ.get('GOOGLE_API_KEY')
def generate_response(input_text):
    with st.spinner('Generating response...'):
        model = ChatGoogleGenerativeAI(
            temperature=0.7,
            model='gemini-2.5-flash',
            api_key=os.environ.get('GOOGLE_API_KEY'),
            timeout=30
        )
        response = model.invoke(input_text)
        st.info(response.content)

with st.form("chatbot template"):
    text = st.text_area(
        "Enter text:",
        "We Would you like to know more about your concerns ? ",
    )

    submitted = st.form_submit_button("Submit")
    if submitted:
        generate_response(text)
# Out:
# 2025-12-17 14:12:37.212 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-17 14:12:37.490
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/matthieumouillon/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-12-17 14:12:37.490 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-17 14:12:37.491 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-17 14:12:37.494 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-17 14:12:37.494 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-17 14:12:37.495 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-17 14:12:37.496 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-17 14:12:37.496 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-17 14:12:37.498 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-17 14:12:37.499 Session state does not function when running a script without `streamlit run`
# 2025-12-17 14:12:37.500 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-17 14:12:37.501 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-17 14:12:37.502 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-17 14:12:37.503 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-17 14:12:37.503 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-17 14:12:37.504 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-17 14:12:37.505 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-17 14:12:37.505 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-17 14:12:37.507 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
